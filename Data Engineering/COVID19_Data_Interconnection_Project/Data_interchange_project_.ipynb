# %% [markdown]
# # Data interchange project COVID-19
# Author: Alla Topp

# %%
import pandas as pd

# %%
# importing COVID data from new york times 
new_york_data = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')

# %%
new_york_data.head(5)
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
len(new_york_data)
# Out:
# 19429

# %%
new_york_data.dtypes
# Out:
# date      object
# state     object
# fips       int64
# cases      int64
# deaths     int64
# dtype: object

# %%
new_york_data['date'] = pd.to_datetime(new_york_data['date'], errors='coerce')

# %%
# checking if there are any missing values in this data set
missing_values_count = new_york_data.isnull().sum()
missing_values_count
# Out:
# date      0
# state     0
# fips      0
# cases     0
# deaths    0
# dtype: int64

# %%
new_york_data.dtypes
# Out:
# date      datetime64[ns]
# state             object
# fips               int64
# cases              int64
# deaths             int64
# dtype: object

# %% [markdown]
# ## Estimated Inpatient Beds Occupied by State Timeseries

# %%
# importing data where hospital bed are oppupied by all patients

patient_all = pd.read_csv('https://healthdata.gov/sites/default/files/estimated_inpatient_all_20210102_1640.csv', thousands = ',')
patient_all.head()
# Out:
#   state collection_date  Inpatient Beds Occupied Estimated  Count LL  \
# 0    CW      2020-12-02                             529819    529480
# 1    CW      2020-12-03                             531844    531528
# 2    CW      2020-12-04                             528558    528238
# 3    CW      2020-12-05                             512030    511673
# 4    CW      2020-12-06                             498694    498341
#
#    Count UL  Percentage of Inpatient Beds Occupied Estimated  Percentage LL  \
# 0    530158                                            74.98          74.90
# 1    532159                                            75.04          74.97
# 2    528879                                            74.62          74.55
# 3    512386                                            72.69          72.59
# 4    499047                                            71.21          71.12
#
#    Percentage UL  Total Inpatient Beds  Total LL  Total UL
# 0          75.05                706920    706592    707248
# 1          75.11                708908    708557    709260
# 2          74.69                708497    708157    708837
# 3          72.80                704537    704132    704943
# 4          71.31                700470    700103    700837

# %%
len(patient_all)
# Out:
# 1612

# %%
patient_all.dtypes
# Out:
# state                                               object
# collection_date                                     object
# Inpatient Beds Occupied Estimated                    int64
# Count LL                                             int64
# Count UL                                             int64
# Percentage of Inpatient Beds Occupied Estimated    float64
# Percentage LL                                      float64
# Percentage UL                                      float64
# Total Inpatient Beds                                 int64
# Total LL                                             int64
# Total UL                                             int64
# dtype: object

# %%
#cols = ['Inpatient Beds Occupied Estimated', 'Count LL', 'Count UL', 'Total Inpatient Beds', 'Total LL', 'Total UL']
#patient_all[cols] = patient_all[cols].apply(pd.to_numeric, errors='ignore', axis=1)

# %%
patient_all['collection_date'] = pd.to_datetime(patient_all['collection_date'], errors='coerce')

# %%
patient_all.dtypes
# Out:
# state                                                      object
# collection_date                                    datetime64[ns]
# Inpatient Beds Occupied Estimated                           int64
# Count LL                                                    int64
# Count UL                                                    int64
# Percentage of Inpatient Beds Occupied Estimated           float64
# Percentage LL                                             float64
# Percentage UL                                             float64
# Total Inpatient Beds                                        int64
# Total LL                                                    int64
# Total UL                                                    int64
# dtype: object

# %%
# checking if there are any missing values in this data set
missing_values_all = patient_all.isnull().sum()
missing_values_all
# Out:
# state                                              0
# collection_date                                    0
# Inpatient Beds Occupied Estimated                  0
# Count LL                                           0
# Count UL                                           0
# Percentage of Inpatient Beds Occupied Estimated    0
# Percentage LL                                      0
# Percentage UL                                      0
# Total Inpatient Beds                               0
# Total LL                                           0
# Total UL                                           0
# dtype: int64

# %% [markdown]
# ## Estimated Inpatient Beds Occupied by COVID-19 Patients by State Timeseries

# %%
# import of data where hospital beds are occupied only by COVID patients
beds_covid = pd.read_csv('https://healthdata.gov/sites/default/files/estimated_inpatient_covid_20210102%201640.csv', thousands = ',')
beds_covid.head()
# Out:
#   state collection_date  \
# 0    CW      2020-12-02
# 1    CW      2020-12-03
# 2    CW      2020-12-04
# 3    CW      2020-12-05
# 4    CW      2020-12-06
#
#    Inpatient Beds Occupied by COVID-19 Patients Estimated  Count LL  Count UL  \
# 0                                             105059         104916    105202
# 1                                             104627         104483    104772
# 2                                             104541         104398    104684
# 3                                             103896         103742    104050
# 4                                             105182         105032    105331
#
#    Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0                                              14.95
# 1                                              14.84
# 2                                              14.84
# 3                                              14.83
# 4                                              15.10
#
#    Percentage LL  Percentage UL  Total Inpatient Beds  Total LL  Total UL
# 0          14.91          14.98                706920    706592    707248
# 1          14.80          14.88                708908    708557    709260
# 2          14.80          14.88                708497    708157    708837
# 3          14.77          14.89                704537    704132    704943
# 4          15.05          15.15                700470    700103    700837

# %%
len(beds_covid)
# Out:
# 1612

# %%
beds_covid['collection_date'] = pd.to_datetime(beds_covid['collection_date'], errors='coerce')

# %%
beds_covid.dtypes
# Out:
# state                                                                           object
# collection_date                                                         datetime64[ns]
# Inpatient Beds Occupied by COVID-19 Patients Estimated                           int64
# Count LL                                                                         int64
# Count UL                                                                         int64
# Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated           float64
# Percentage LL                                                                  float64
# Percentage UL                                                                  float64
# Total Inpatient Beds                                                             int64
# Total LL                                                                         int64
# Total UL                                                                         int64
# dtype: object

# %% [markdown]
# ## Estimated ICU Beds Occupied by State Timeseries

# %%
# import data where occupied beds are by ICU patients 

icu_beds = pd.read_csv('https://healthdata.gov/sites/default/files/estimated_icu_20210102_1640.csv', thousands = ',')
icu_beds.head()
# Out:
#   state collection_date  Staffed Adult ICU Beds Occupied Estimated  Count LL  \
# 0    CW      2020-12-02                                      65922     65894
# 1    CW      2020-12-03                                      66429     66394
# 2    CW      2020-12-04                                      66448     66384
# 3    CW      2020-12-05                                      65819     65759
# 4    CW      2020-12-06                                      64681     64622
#
#    Count UL  Percentage of Staffed Adult ICU Beds Occupied Estimated  \
# 0     65950                                              77.32
# 1     66463                                              77.72
# 2     66512                                              77.60
# 3     65880                                              77.03
# 4     64739                                              75.98
#
#    Percentage LL  Percentage UL  Total Staffed Adult ICU Beds  Total LL  \
# 0          77.25          77.38                         85282     85263
# 1          77.62          77.82                         85486     85455
# 2          77.43          77.77                         85638     85618
# 3          76.85          77.21                         85454     85408
# 4          75.79          76.18                         85132     85073
#
#    Total UL
# 0     85301
# 1     85516
# 2     85659
# 3     85501
# 4     85191

# %%
len(icu_beds)
# Out:
# 1612

# %%
icu_beds['collection_date'] = pd.to_datetime(icu_beds['collection_date'], errors='coerce')

# %%
icu_beds.dtypes
# Out:
# state                                                              object
# collection_date                                            datetime64[ns]
# Staffed Adult ICU Beds Occupied Estimated                           int64
# Count LL                                                            int64
# Count UL                                                            int64
# Percentage of Staffed Adult ICU Beds Occupied Estimated           float64
# Percentage LL                                                     float64
# Percentage UL                                                     float64
# Total Staffed Adult ICU Beds                                        int64
# Total LL                                                            int64
# Total UL                                                            int64
# dtype: object

# %% [markdown]
# # Merging data sets

# %% [markdown]
# ### First, merging 3 healthdata.gov datasets

# %%
# merging all patients dataset and covid patients dataset 
mrd = pd.merge(patient_all, beds_covid, on = ['state', 'collection_date'])
mrd.head()
# Out:
#   state collection_date  Inpatient Beds Occupied Estimated  Count LL_x  \
# 0    CW      2020-12-02                             529819      529480
# 1    CW      2020-12-03                             531844      531528
# 2    CW      2020-12-04                             528558      528238
# 3    CW      2020-12-05                             512030      511673
# 4    CW      2020-12-06                             498694      498341
#
#    Count UL_x  Percentage of Inpatient Beds Occupied Estimated  \
# 0      530158                                            74.98
# 1      532159                                            75.04
# 2      528879                                            74.62
# 3      512386                                            72.69
# 4      499047                                            71.21
#
#    Percentage LL_x  Percentage UL_x  Total Inpatient Beds_x  Total LL_x  \
# 0            74.90            75.05                  706920      706592
# 1            74.97            75.11                  708908      708557
# 2            74.55            74.69                  708497      708157
# 3            72.59            72.80                  704537      704132
# 4            71.12            71.31                  700470      700103
#
#    Total UL_x  Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0      707248                                             105059
# 1      709260                                             104627
# 2      708837                                             104541
# 3      704943                                             103896
# 4      700837                                             105182
#
#    Count LL_y  Count UL_y  \
# 0      104916      105202
# 1      104483      104772
# 2      104398      104684
# 3      103742      104050
# 4      105032      105331
#
#    Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0                                              14.95
# 1                                              14.84
# 2                                              14.84
# 3                                              14.83
# 4                                              15.10
#
#    Percentage LL_y  Percentage UL_y  Total Inpatient Beds_y  Total LL_y  \
# 0            14.91            14.98                  706920      706592
# 1            14.80            14.88                  708908      708557
# 2            14.80            14.88                  708497      708157
# 3            14.77            14.89                  704537      704132
# 4            15.05            15.15                  700470      700103
#
#    Total UL_y
# 0      707248
# 1      709260
# 2      708837
# 3      704943
# 4      700837

# %%
all_beds = pd.merge(mrd, icu_beds, on = ['state', 'collection_date'])
all_beds
# Out:
#      state collection_date  Inpatient Beds Occupied Estimated  Count LL_x  \
# 0       CW      2020-12-02                             529819      529480
# 1       CW      2020-12-03                             531844      531528
# 2       CW      2020-12-04                             528558      528238
# 3       CW      2020-12-05                             512030      511673
# 4       CW      2020-12-06                             498694      498341
# ...    ...             ...                                ...         ...
# 1607    WI      2020-12-28                               7350        7349
# 1608    WI      2020-12-29                               7720        7661
# 1609    WI      2020-12-30                               7830        7779
# 1610    WI      2020-12-31                               7823        7760
# 1611    WI      2021-01-01                               7484        7365
#
#       Count UL_x  Percentage of Inpatient Beds Occupied Estimated  \
# 0         530158                                            74.98
# 1         532159                                            75.04
# 2         528879                                            74.62
# 3         512386                                            72.69
# 4         499047                                            71.21
# ...          ...                                              ...
# 1607        7351                                            58.93
# 1608        7780                                            61.71
# 1609        7882                                            62.55
# 1610        7886                                            62.49
# 1611        7603                                            60.08
#
#       Percentage LL_x  Percentage UL_x  Total Inpatient Beds_x  Total LL_x  \
# 0               74.90            75.05                  706920      706592
# 1               74.97            75.11                  708908      708557
# 2               74.55            74.69                  708497      708157
# 3               72.59            72.80                  704537      704132
# 4               71.12            71.31                  700470      700103
# ...               ...              ...                     ...         ...
# 1607            58.93            58.93                   12473       12473
# 1608            60.49            62.94                   12510       12499
# 1609            61.08            64.02                   12518       12437
# 1610            60.73            64.26                   12518       12421
# 1611            56.91            63.25                   12457       12297
#
#       ...  Total UL_y  Staffed Adult ICU Beds Occupied Estimated  Count LL  \
# 0     ...      707248                                      65922     65894
# 1     ...      709260                                      66429     66394
# 2     ...      708837                                      66448     66384
# 3     ...      704943                                      65819     65759
# 4     ...      700837                                      64681     64622
# ...   ...         ...                                        ...       ...
# 1607  ...       12473                                        900       900
# 1608  ...       12521                                        948       942
# 1609  ...       12599                                        972       962
# 1610  ...       12615                                        943       931
# 1611  ...       12617                                        917       901
#
#       Count UL  Percentage of Staffed Adult ICU Beds Occupied Estimated  \
# 0        65950                                              77.32
# 1        66463                                              77.72
# 2        66512                                              77.60
# 3        65880                                              77.03
# 4        64739                                              75.98
# ...        ...                                                ...
# 1607       900                                              55.83
# 1608       954                                              58.55
# 1609       981                                              59.90
# 1610       955                                              58.39
# 1611       933                                              56.71
#
#       Percentage LL  Percentage UL  Total Staffed Adult ICU Beds  Total LL  \
# 0             77.25          77.38                         85282     85263
# 1             77.62          77.82                         85486     85455
# 2             77.43          77.77                         85638     85618
# 3             76.85          77.21                         85454     85408
# 4             75.79          76.18                         85132     85073
# ...             ...            ...                           ...       ...
# 1607          55.83          55.83                          1612      1612
# 1608          57.57          59.54                          1619      1619
# 1609          57.65          62.14                          1622      1605
# 1610          55.63          61.15                          1615      1594
# 1611          53.15          60.27                          1617      1591
#
#       Total UL
# 0        85301
# 1        85516
# 2        85659
# 3        85501
# 4        85191
# ...        ...
# 1607      1612
# 1608      1619
# 1609      1639
# 1610      1636
# 1611      1643
#
# [1612 rows x 29 columns]

# %%
# changing the name of column collection_date to date like other dataset has
all_beds.rename(columns = {'collection_date':'date'}, inplace = True) 
all_beds.head()
# Out:
#   state       date  Inpatient Beds Occupied Estimated  Count LL_x  Count UL_x  \
# 0    CW 2020-12-02                             529819      529480      530158
# 1    CW 2020-12-03                             531844      531528      532159
# 2    CW 2020-12-04                             528558      528238      528879
# 3    CW 2020-12-05                             512030      511673      512386
# 4    CW 2020-12-06                             498694      498341      499047
#
#    Percentage of Inpatient Beds Occupied Estimated  Percentage LL_x  \
# 0                                            74.98            74.90
# 1                                            75.04            74.97
# 2                                            74.62            74.55
# 3                                            72.69            72.59
# 4                                            71.21            71.12
#
#    Percentage UL_x  Total Inpatient Beds_x  Total LL_x  ...  Total UL_y  \
# 0            75.05                  706920      706592  ...      707248
# 1            75.11                  708908      708557  ...      709260
# 2            74.69                  708497      708157  ...      708837
# 3            72.80                  704537      704132  ...      704943
# 4            71.31                  700470      700103  ...      700837
#
#    Staffed Adult ICU Beds Occupied Estimated  Count LL  Count UL  \
# 0                                      65922     65894     65950
# 1                                      66429     66394     66463
# 2                                      66448     66384     66512
# 3                                      65819     65759     65880
# 4                                      64681     64622     64739
#
#    Percentage of Staffed Adult ICU Beds Occupied Estimated  Percentage LL  \
# 0                                              77.32                77.25
# 1                                              77.72                77.62
# 2                                              77.60                77.43
# 3                                              77.03                76.85
# 4                                              75.98                75.79
#
#    Percentage UL  Total Staffed Adult ICU Beds  Total LL  Total UL
# 0          77.38                         85282     85263     85301
# 1          77.82                         85486     85455     85516
# 2          77.77                         85638     85618     85659
# 3          77.21                         85454     85408     85501
# 4          76.18                         85132     85073     85191
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Remapping dataframe to translate US States to Two letter codes

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
new_york_data['state'] = new_york_data['state'].map(us_state_abbrev)

# %%
print(new_york_data)
# Out:
#             date state  fips   cases  deaths
# 0     2020-01-21    WA    53       1       0
# 1     2020-01-22    WA    53       1       0
# 2     2020-01-23    WA    53       1       0
# 3     2020-01-24    IL    17       1       0
# 4     2020-01-24    WA    53       1       0
# ...          ...   ...   ...     ...     ...
# 19424 2021-02-18    VA    51  557896    7090
# 19425 2021-02-18    WA    53  335338    4868
# 19426 2021-02-18    WV    54  128760    2236
# 19427 2021-02-18    WI    55  610056    6820
# 19428 2021-02-18    WY    56   53531     662
#
# [19429 rows x 5 columns]

# %% [markdown]
# ### Final merge

# %%
final_dataset = pd.merge(new_york_data, all_beds, on = ['state', 'date'])
final_dataset
# Out:
#            date state  fips    cases  deaths  \
# 0    2020-12-02    AL     1   256828    3711
# 1    2020-12-02    AK     2    33614     116
# 2    2020-12-02    AZ     4   342925    6755
# 3    2020-12-02    AR     5   161521    2522
# 4    2020-12-02    CA     6  1272041   19440
# ...         ...   ...   ...      ...     ...
# 1576 2021-01-01    VA    51   354766    5081
# 1577 2021-01-01    WA    53   251585    3523
# 1578 2021-01-01    WV    54    87820    1361
# 1579 2021-01-01    WI    55   522523    5257
# 1580 2021-01-01    WY    56    44409     438
#
#       Inpatient Beds Occupied Estimated  Count LL_x  Count UL_x  \
# 0                                 11036       11036       11036
# 1                                   933         933         933
# 2                                 10620       10613       10627
# 3                                  5531        5531        5531
# 4                                 47713       47665       47761
# ...                                 ...         ...         ...
# 1576                              11402       10991       11813
# 1577                               8450        8331        8569
# 1578                               3745        3745        3745
# 1579                               7484        7365        7603
# 1580                                576         567         585
#
#       Percentage of Inpatient Beds Occupied Estimated  Percentage LL_x  ...  \
# 0                                               77.89            77.89  ...
# 1                                               65.02            65.02  ...
# 2                                               76.94            76.75  ...
# 3                                               73.53            73.53  ...
# 4                                               75.98            75.91  ...
# ...                                               ...              ...  ...
# 1576                                            69.44            61.40  ...
# 1577                                            67.61            64.25  ...
# 1578                                            74.90            74.90  ...
# 1579                                            60.08            56.91  ...
# 1580                                            40.06            37.48  ...
#
#       Total UL_y  Staffed Adult ICU Beds Occupied Estimated  Count LL  \
# 0          14168                                       1312      1312
# 1           1435                                        103       103
# 2          13815                                       1389      1389
# 3           7522                                        822       822
# 4          62919                                       5862      5855
# ...          ...                                        ...       ...
# 1576       16947                                       1413      1356
# 1577       12683                                        951       950
# 1578        5000                                        509       509
# 1579       12617                                        917       901
# 1580        1457                                         52        50
#
#       Count UL  Percentage of Staffed Adult ICU Beds Occupied Estimated  \
# 0         1312                                              88.53
# 1          103                                              81.10
# 2         1389                                              69.83
# 3          822                                              80.99
# 4         5869                                              79.70
# ...        ...                                                ...
# 1576      1470                                              72.54
# 1577       952                                              70.50
# 1578       509                                              83.17
# 1579       933                                              56.71
# 1580        54                                              40.94
#
#       Percentage LL  Percentage UL  Total Staffed Adult ICU Beds  Total LL  \
# 0             88.53          88.53                          1482      1482
# 1             81.10          81.10                           127       127
# 2             69.83          69.83                          1989      1989
# 3             80.99          80.99                          1015      1015
# 4             79.70          79.70                          7369      7365
# ...             ...            ...                           ...       ...
# 1576          63.50          81.57                          1948      1881
# 1577          69.96          71.03                          1349      1345
# 1578          83.17          83.17                           612       596
# 1579          53.15          60.27                          1617      1591
# 1580          36.26          45.63                           127       124
#
#       Total UL
# 0         1482
# 1          127
# 2         1989
# 3         1015
# 4         7373
# ...        ...
# 1576      2015
# 1577      1353
# 1578       628
# 1579      1643
# 1580       130
#
# [1581 rows x 32 columns]

# %% [markdown]
# ## Changing LL and UL column names

# %%
final_dataset.rename(columns = {'Count LL_x':'Count LL_inpatient beds occupied'}, inplace = True) 
final_dataset.rename(columns = {'Count UL_x':'Count UL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage LL_x':'Percentage LL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage UL_x':'Percentage UL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Total LL_x':'Total LL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Total UL_x':'Total UL_inpatient beds occupied'}, inplace = True)

# %%
final_dataset.rename(columns = {'Count LL_y':'Count LL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Count UL_y':'Count UL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Percentage LL_y':'Percentage LL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Percentage UL_y':'Percentage UL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Total LL_y':'Total LL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Total UL_y':'Total UL_occupied by COVID-19 patients'}, inplace = True)

# %%
final_dataset.rename(columns = {'Count LL':'Count LL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Count UL':'Count UL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage LL':'Percentage LL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage UL':'Percentage UL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Total LL':'Total LL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Total UL':'Total UL_ICU Beds Occupied'}, inplace = True)

# %% [markdown]
# ## Final dataset column names

# %%
# list of columns in final dataset
list(final_dataset.columns)
# Out:
# ['date',
#  'state',
#  'fips',
#  'cases',
#  'deaths',
#  'Inpatient Beds Occupied Estimated',
#  'Count LL_inpatient beds occupied',
#  'Count UL_inpatient beds occupied',
#  'Percentage of Inpatient Beds Occupied Estimated',
#  'Percentage LL_inpatient beds occupied',
#  'Percentage UL_inpatient beds occupied',
#  'Total Inpatient Beds_x',
#  'Total LL_inpatient beds occupied',
#  'Total UL_inpatient beds occupied',
#  'Inpatient Beds Occupied by COVID-19 Patients Estimated',
#  'Count LL_occupied by COVID-19 patients',
#  'Count UL_occupied by COVID-19 patients',
#  'Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated',
#  'Percentage LL_occupied by COVID-19 patients',
#  'Percentage UL_occupied by COVID-19 patients',
#  'Total Inpatient Beds_y',
#  'Total LL_occupied by COVID-19 patients',
#  'Total UL_occupied by COVID-19 patients',
#  'Staffed Adult ICU Beds Occupied Estimated',
#  'Count LL_ICU Beds Occupied',
#  'Count UL_ICU Beds Occupied',
#  'Percentage of Staffed Adult ICU Beds Occupied Estimated',
#  'Percentage LL_ICU Beds Occupied',
#  'Percentage UL_ICU Beds Occupied',
#  'Total Staffed Adult ICU Beds',
#  'Total LL_ICU Beds Occupied',
#  'Total UL_ICU Beds Occupied']

# %% [markdown]
# ## Checking the final dataset

# %%
final_dataset
# Out:
#            date state  fips    cases  deaths  \
# 0    2020-12-02    AL     1   256828    3711
# 1    2020-12-02    AK     2    33614     116
# 2    2020-12-02    AZ     4   342925    6755
# 3    2020-12-02    AR     5   161521    2522
# 4    2020-12-02    CA     6  1272041   19440
# ...         ...   ...   ...      ...     ...
# 1576 2021-01-01    VA    51   354766    5081
# 1577 2021-01-01    WA    53   251585    3523
# 1578 2021-01-01    WV    54    87820    1361
# 1579 2021-01-01    WI    55   522523    5257
# 1580 2021-01-01    WY    56    44409     438
#
#       Inpatient Beds Occupied Estimated  Count LL_inpatient beds occupied  \
# 0                                 11036                             11036
# 1                                   933                               933
# 2                                 10620                             10613
# 3                                  5531                              5531
# 4                                 47713                             47665
# ...                                 ...                               ...
# 1576                              11402                             10991
# 1577                               8450                              8331
# 1578                               3745                              3745
# 1579                               7484                              7365
# 1580                                576                               567
#
#       Count UL_inpatient beds occupied  \
# 0                                11036
# 1                                  933
# 2                                10627
# 3                                 5531
# 4                                47761
# ...                                ...
# 1576                             11813
# 1577                              8569
# 1578                              3745
# 1579                              7603
# 1580                               585
#
#       Percentage of Inpatient Beds Occupied Estimated  \
# 0                                               77.89
# 1                                               65.02
# 2                                               76.94
# 3                                               73.53
# 4                                               75.98
# ...                                               ...
# 1576                                            69.44
# 1577                                            67.61
# 1578                                            74.90
# 1579                                            60.08
# 1580                                            40.06
#
#       Percentage LL_inpatient beds occupied  ...  \
# 0                                     77.89  ...
# 1                                     65.02  ...
# 2                                     76.75  ...
# 3                                     73.53  ...
# 4                                     75.91  ...
# ...                                     ...  ...
# 1576                                  61.40  ...
# 1577                                  64.25  ...
# 1578                                  74.90  ...
# 1579                                  56.91  ...
# 1580                                  37.48  ...
#
#       Total UL_occupied by COVID-19 patients  \
# 0                                      14168
# 1                                       1435
# 2                                      13815
# 3                                       7522
# 4                                      62919
# ...                                      ...
# 1576                                   16947
# 1577                                   12683
# 1578                                    5000
# 1579                                   12617
# 1580                                    1457
#
#       Staffed Adult ICU Beds Occupied Estimated  Count LL_ICU Beds Occupied  \
# 0                                          1312                        1312
# 1                                           103                         103
# 2                                          1389                        1389
# 3                                           822                         822
# 4                                          5862                        5855
# ...                                         ...                         ...
# 1576                                       1413                        1356
# 1577                                        951                         950
# 1578                                        509                         509
# 1579                                        917                         901
# 1580                                         52                          50
#
#       Count UL_ICU Beds Occupied  \
# 0                           1312
# 1                            103
# 2                           1389
# 3                            822
# 4                           5869
# ...                          ...
# 1576                        1470
# 1577                         952
# 1578                         509
# 1579                         933
# 1580                          54
#
#       Percentage of Staffed Adult ICU Beds Occupied Estimated  \
# 0                                                 88.53
# 1                                                 81.10
# 2                                                 69.83
# 3                                                 80.99
# 4                                                 79.70
# ...                                                 ...
# 1576                                              72.54
# 1577                                              70.50
# 1578                                              83.17
# 1579                                              56.71
# 1580                                              40.94
#
#       Percentage LL_ICU Beds Occupied  Percentage UL_ICU Beds Occupied  \
# 0                               88.53                            88.53
# 1                               81.10                            81.10
# 2                               69.83                            69.83
# 3                               80.99                            80.99
# 4                               79.70                            79.70
# ...                               ...                              ...
# 1576                            63.50                            81.57
# 1577                            69.96                            71.03
# 1578                            83.17                            83.17
# 1579                            53.15                            60.27
# 1580                            36.26                            45.63
#
#       Total Staffed Adult ICU Beds  Total LL_ICU Beds Occupied  \
# 0                             1482                        1482
# 1                              127                         127
# 2                             1989                        1989
# 3                             1015                        1015
# 4                             7369                        7365
# ...                            ...                         ...
# 1576                          1948                        1881
# 1577                          1349                        1345
# 1578                           612                         596
# 1579                          1617                        1591
# 1580                           127                         124
#
#       Total UL_ICU Beds Occupied
# 0                           1482
# 1                            127
# 2                           1989
# 3                           1015
# 4                           7373
# ...                          ...
# 1576                        2015
# 1577                        1353
# 1578                         628
# 1579                        1643
# 1580                         130
#
# [1581 rows x 32 columns]

# %% [markdown]
# ### Export of the files

# %%
# final_dataset.to_csv('final_covid.csv')
# fnl_covid.to_json('file.json', orient = 'split', compression = 'infer', index = 'true') 
# https://towardsdatascience.com/automatically-update-data-sources-in-python-e424dbea68d0

# %% [markdown]
# ### Reference:
# * Data Import (https://www.datacamp.com/community/tutorials/importing-data-into-pandas)
# * Dict map (https://gist.github.com/rogerallen/1583593)
# * Pandas Indexing (https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/)
# * Remap (https://www.geeksforgeeks.org/using-dictionary-to-remap-values-in-pandas-dataframe-columns/)
# * NYT data (https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv)
# * Healthdata.gov data (https://healthdata.gov/dataset/covid-19-estimated-patient-impact-and-hospital-capacity-state)
