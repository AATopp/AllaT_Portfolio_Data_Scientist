# %% [markdown]
# # Data interchange project

# %%
import pandas as pd

# %%
# importing COVID data from new york times 
new_york_data = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')

# %%
new_york_data.head(5)
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
len(new_york_data)
# Out:
# 19209

# %%
# checking if there are any missing values in this data set
missing_values_count = new_york_data.isnull().sum()
missing_values_count
# Out:
# date      0
# state     0
# fips      0
# cases     0
# deaths    0
# dtype: int64

# %% [markdown]
# ### Remapping dataframe to translate US States to Two letter codes

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
new_york_data['state'] = new_york_data['state'].map(us_state_abbrev)

# %%
print(new_york_data)
# Out:
#              date state  fips   cases  deaths
# 0      2020-01-21    WA    53       1       0
# 1      2020-01-22    WA    53       1       0
# 2      2020-01-23    WA    53       1       0
# 3      2020-01-24    IL    17       1       0
# 4      2020-01-24    WA    53       1       0
# ...           ...   ...   ...     ...     ...
# 19204  2021-02-14    VA    51  549999    7012
# 19205  2021-02-14    WA    53  331164    4739
# 19206  2021-02-14    WV    54  127588    2210
# 19207  2021-02-14    WI    55  607213    6748
# 19208  2021-02-14    WY    56   53136     647
#
# [19209 rows x 5 columns]

# %% [markdown]
# ## Estimated Inpatient Beds Occupied by State Timeseries

# %%
# importing data where hospital bed are oppupied by all patients

patient_all = pd.read_csv('https://healthdata.gov/sites/default/files/estimated_inpatient_all_20210102_1640.csv')
patient_all.head()
# Out:
#   state collection_date Inpatient Beds Occupied Estimated Count LL Count UL  \
# 0    CW      2020-12-02                           529,819  529,480  530,158
# 1    CW      2020-12-03                           531,844  531,528  532,159
# 2    CW      2020-12-04                           528,558  528,238  528,879
# 3    CW      2020-12-05                           512,030  511,673  512,386
# 4    CW      2020-12-06                           498,694  498,341  499,047
#
#    Percentage of Inpatient Beds Occupied Estimated  Percentage LL  \
# 0                                            74.98          74.90
# 1                                            75.04          74.97
# 2                                            74.62          74.55
# 3                                            72.69          72.59
# 4                                            71.21          71.12
#
#    Percentage UL Total Inpatient Beds Total LL Total UL
# 0          75.05              706,920  706,592  707,248
# 1          75.11              708,908  708,557  709,260
# 2          74.69              708,497  708,157  708,837
# 3          72.80              704,537  704,132  704,943
# 4          71.31              700,470  700,103  700,837

# %%
len(patient_all)
# Out:
# 1612

# %% [markdown]
# ## Estimated Inpatient Beds Occupied by COVID-19 Patients by State Timeseries

# %%
# import of data where hospital beds are occupied only by COVID patients

beds_covid = pd.read_csv('https://healthdata.gov/sites/default/files/estimated_inpatient_covid_20210102%201640.csv')
beds_covid.head()
# Out:
#   state collection_date  \
# 0    CW      2020-12-02
# 1    CW      2020-12-03
# 2    CW      2020-12-04
# 3    CW      2020-12-05
# 4    CW      2020-12-06
#
#   Inpatient Beds Occupied by COVID-19 Patients Estimated Count LL Count UL  \
# 0                                            105,059      104,916  105,202
# 1                                            104,627      104,483  104,772
# 2                                            104,541      104,398  104,684
# 3                                            103,896      103,742  104,050
# 4                                            105,182      105,032  105,331
#
#    Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0                                              14.95
# 1                                              14.84
# 2                                              14.84
# 3                                              14.83
# 4                                              15.10
#
#    Percentage LL  Percentage UL Total Inpatient Beds Total LL Total UL
# 0          14.91          14.98              706,920  706,592  707,248
# 1          14.80          14.88              708,908  708,557  709,260
# 2          14.80          14.88              708,497  708,157  708,837
# 3          14.77          14.89              704,537  704,132  704,943
# 4          15.05          15.15              700,470  700,103  700,837

# %%
len(beds_covid)
# Out:
# 1612

# %% [markdown]
# ## Estimated ICU Beds Occupied by State Timeseries

# %%
# import data where occupied beds are by ICU patients 

icu_beds = pd.read_csv('https://healthdata.gov/sites/default/files/estimated_icu_20210102_1640.csv')
icu_beds.head()
# Out:
#   state collection_date Staffed Adult ICU Beds Occupied Estimated Count LL  \
# 0    CW      2020-12-02                                    65,922   65,894
# 1    CW      2020-12-03                                    66,429   66,394
# 2    CW      2020-12-04                                    66,448   66,384
# 3    CW      2020-12-05                                    65,819   65,759
# 4    CW      2020-12-06                                    64,681   64,622
#
#   Count UL  Percentage of Staffed Adult ICU Beds Occupied Estimated  \
# 0   65,950                                              77.32
# 1   66,463                                              77.72
# 2   66,512                                              77.60
# 3   65,880                                              77.03
# 4   64,739                                              75.98
#
#    Percentage LL  Percentage UL Total Staffed Adult ICU Beds Total LL Total UL
# 0          77.25          77.38                       85,282   85,263   85,301
# 1          77.62          77.82                       85,486   85,455   85,516
# 2          77.43          77.77                       85,638   85,618   85,659
# 3          76.85          77.21                       85,454   85,408   85,501
# 4          75.79          76.18                       85,132   85,073   85,191

# %%
len(icu_beds)
# Out:
# 1612

# %% [markdown]
# # Merging data sets

# %% [markdown]
# ### First, merging 3 healthdata.gov datasets

# %%
# merging all patients dataset and covid patients dataset 
mrd = pd.merge(patient_all, beds_covid, on = ['state', 'collection_date'])
mrd.head()
# Out:
#   state collection_date Inpatient Beds Occupied Estimated Count LL_x  \
# 0    CW      2020-12-02                           529,819    529,480
# 1    CW      2020-12-03                           531,844    531,528
# 2    CW      2020-12-04                           528,558    528,238
# 3    CW      2020-12-05                           512,030    511,673
# 4    CW      2020-12-06                           498,694    498,341
#
#   Count UL_x  Percentage of Inpatient Beds Occupied Estimated  \
# 0    530,158                                            74.98
# 1    532,159                                            75.04
# 2    528,879                                            74.62
# 3    512,386                                            72.69
# 4    499,047                                            71.21
#
#    Percentage LL_x  Percentage UL_x Total Inpatient Beds_x Total LL_x  \
# 0            74.90            75.05                706,920    706,592
# 1            74.97            75.11                708,908    708,557
# 2            74.55            74.69                708,497    708,157
# 3            72.59            72.80                704,537    704,132
# 4            71.12            71.31                700,470    700,103
#
#   Total UL_x Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0    707,248                                            105,059
# 1    709,260                                            104,627
# 2    708,837                                            104,541
# 3    704,943                                            103,896
# 4    700,837                                            105,182
#
#   Count LL_y Count UL_y  \
# 0    104,916    105,202
# 1    104,483    104,772
# 2    104,398    104,684
# 3    103,742    104,050
# 4    105,032    105,331
#
#    Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0                                              14.95
# 1                                              14.84
# 2                                              14.84
# 3                                              14.83
# 4                                              15.10
#
#    Percentage LL_y  Percentage UL_y Total Inpatient Beds_y Total LL_y  \
# 0            14.91            14.98                706,920    706,592
# 1            14.80            14.88                708,908    708,557
# 2            14.80            14.88                708,497    708,157
# 3            14.77            14.89                704,537    704,132
# 4            15.05            15.15                700,470    700,103
#
#   Total UL_y
# 0    707,248
# 1    709,260
# 2    708,837
# 3    704,943
# 4    700,837

# %%
all_beds = pd.merge(mrd, icu_beds, on = ['state', 'collection_date'])
all_beds
# Out:
#      state collection_date Inpatient Beds Occupied Estimated Count LL_x  \
# 0       CW      2020-12-02                           529,819    529,480
# 1       CW      2020-12-03                           531,844    531,528
# 2       CW      2020-12-04                           528,558    528,238
# 3       CW      2020-12-05                           512,030    511,673
# 4       CW      2020-12-06                           498,694    498,341
# ...    ...             ...                               ...        ...
# 1607    WI      2020-12-28                             7,350      7,349
# 1608    WI      2020-12-29                             7,720      7,661
# 1609    WI      2020-12-30                             7,830      7,779
# 1610    WI      2020-12-31                             7,823      7,760
# 1611    WI      2021-01-01                             7,484      7,365
#
#      Count UL_x  Percentage of Inpatient Beds Occupied Estimated  \
# 0       530,158                                            74.98
# 1       532,159                                            75.04
# 2       528,879                                            74.62
# 3       512,386                                            72.69
# 4       499,047                                            71.21
# ...         ...                                              ...
# 1607      7,351                                            58.93
# 1608      7,780                                            61.71
# 1609      7,882                                            62.55
# 1610      7,886                                            62.49
# 1611      7,603                                            60.08
#
#       Percentage LL_x  Percentage UL_x Total Inpatient Beds_x Total LL_x  ...  \
# 0               74.90            75.05                706,920    706,592  ...
# 1               74.97            75.11                708,908    708,557  ...
# 2               74.55            74.69                708,497    708,157  ...
# 3               72.59            72.80                704,537    704,132  ...
# 4               71.12            71.31                700,470    700,103  ...
# ...               ...              ...                    ...        ...  ...
# 1607            58.93            58.93                 12,473     12,473  ...
# 1608            60.49            62.94                 12,510     12,499  ...
# 1609            61.08            64.02                 12,518     12,437  ...
# 1610            60.73            64.26                 12,518     12,421  ...
# 1611            56.91            63.25                 12,457     12,297  ...
#
#      Total UL_y Staffed Adult ICU Beds Occupied Estimated Count LL Count UL  \
# 0       707,248                                    65,922   65,894   65,950
# 1       709,260                                    66,429   66,394   66,463
# 2       708,837                                    66,448   66,384   66,512
# 3       704,943                                    65,819   65,759   65,880
# 4       700,837                                    64,681   64,622   64,739
# ...         ...                                       ...      ...      ...
# 1607     12,473                                       900      900      900
# 1608     12,521                                       948      942      954
# 1609     12,599                                       972      962      981
# 1610     12,615                                       943      931      955
# 1611     12,617                                       917      901      933
#
#       Percentage of Staffed Adult ICU Beds Occupied Estimated  Percentage LL  \
# 0                                                 77.32                77.25
# 1                                                 77.72                77.62
# 2                                                 77.60                77.43
# 3                                                 77.03                76.85
# 4                                                 75.98                75.79
# ...                                                 ...                  ...
# 1607                                              55.83                55.83
# 1608                                              58.55                57.57
# 1609                                              59.90                57.65
# 1610                                              58.39                55.63
# 1611                                              56.71                53.15
#
#       Percentage UL Total Staffed Adult ICU Beds Total LL Total UL
# 0             77.38                       85,282   85,263   85,301
# 1             77.82                       85,486   85,455   85,516
# 2             77.77                       85,638   85,618   85,659
# 3             77.21                       85,454   85,408   85,501
# 4             76.18                       85,132   85,073   85,191
# ...             ...                          ...      ...      ...
# 1607          55.83                        1,612    1,612    1,612
# 1608          59.54                        1,619    1,619    1,619
# 1609          62.14                        1,622    1,605    1,639
# 1610          61.15                        1,615    1,594    1,636
# 1611          60.27                        1,617    1,591    1,643
#
# [1612 rows x 29 columns]

# %%
# changing the name of column collection_date to date like other dataset has
all_beds.rename(columns = {'collection_date':'date'}, inplace = True) 
all_beds.head()
# Out:
#   state        date Inpatient Beds Occupied Estimated Count LL_x Count UL_x  \
# 0    CW  2020-12-02                           529,819    529,480    530,158
# 1    CW  2020-12-03                           531,844    531,528    532,159
# 2    CW  2020-12-04                           528,558    528,238    528,879
# 3    CW  2020-12-05                           512,030    511,673    512,386
# 4    CW  2020-12-06                           498,694    498,341    499,047
#
#    Percentage of Inpatient Beds Occupied Estimated  Percentage LL_x  \
# 0                                            74.98            74.90
# 1                                            75.04            74.97
# 2                                            74.62            74.55
# 3                                            72.69            72.59
# 4                                            71.21            71.12
#
#    Percentage UL_x Total Inpatient Beds_x Total LL_x  ... Total UL_y  \
# 0            75.05                706,920    706,592  ...    707,248
# 1            75.11                708,908    708,557  ...    709,260
# 2            74.69                708,497    708,157  ...    708,837
# 3            72.80                704,537    704,132  ...    704,943
# 4            71.31                700,470    700,103  ...    700,837
#
#   Staffed Adult ICU Beds Occupied Estimated Count LL Count UL  \
# 0                                    65,922   65,894   65,950
# 1                                    66,429   66,394   66,463
# 2                                    66,448   66,384   66,512
# 3                                    65,819   65,759   65,880
# 4                                    64,681   64,622   64,739
#
#    Percentage of Staffed Adult ICU Beds Occupied Estimated  Percentage LL  \
# 0                                              77.32                77.25
# 1                                              77.72                77.62
# 2                                              77.60                77.43
# 3                                              77.03                76.85
# 4                                              75.98                75.79
#
#    Percentage UL Total Staffed Adult ICU Beds Total LL Total UL
# 0          77.38                       85,282   85,263   85,301
# 1          77.82                       85,486   85,455   85,516
# 2          77.77                       85,638   85,618   85,659
# 3          77.21                       85,454   85,408   85,501
# 4          76.18                       85,132   85,073   85,191
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Final merge

# %%
final_dataset = pd.merge(new_york_data, all_beds, on = ['state', 'date'])
final_dataset
# Out:
#             date state  fips    cases  deaths  \
# 0     2020-12-02    AL     1   256828    3711
# 1     2020-12-02    AK     2    33614     116
# 2     2020-12-02    AZ     4   342925    6755
# 3     2020-12-02    AR     5   161521    2522
# 4     2020-12-02    CA     6  1272041   19440
# ...          ...   ...   ...      ...     ...
# 1576  2021-01-01    VA    51   354766    5081
# 1577  2021-01-01    WA    53   251585    3523
# 1578  2021-01-01    WV    54    87820    1361
# 1579  2021-01-01    WI    55   522523    5257
# 1580  2021-01-01    WY    56    44409     438
#
#      Inpatient Beds Occupied Estimated Count LL_x Count UL_x  \
# 0                               11,036     11,036     11,036
# 1                                  933        933        933
# 2                               10,620     10,613     10,627
# 3                                5,531      5,531      5,531
# 4                               47,713     47,665     47,761
# ...                                ...        ...        ...
# 1576                            11,402     10,991     11,813
# 1577                             8,450      8,331      8,569
# 1578                             3,745      3,745      3,745
# 1579                             7,484      7,365      7,603
# 1580                               576        567        585
#
#       Percentage of Inpatient Beds Occupied Estimated  Percentage LL_x  ...  \
# 0                                               77.89            77.89  ...
# 1                                               65.02            65.02  ...
# 2                                               76.94            76.75  ...
# 3                                               73.53            73.53  ...
# 4                                               75.98            75.91  ...
# ...                                               ...              ...  ...
# 1576                                            69.44            61.40  ...
# 1577                                            67.61            64.25  ...
# 1578                                            74.90            74.90  ...
# 1579                                            60.08            56.91  ...
# 1580                                            40.06            37.48  ...
#
#       Total UL_y Staffed Adult ICU Beds Occupied Estimated Count LL Count UL  \
# 0         14,168                                     1,312    1,312    1,312
# 1          1,435                                       103      103      103
# 2         13,815                                     1,389    1,389    1,389
# 3          7,522                                       822      822      822
# 4         62,919                                     5,862    5,855    5,869
# ...          ...                                       ...      ...      ...
# 1576      16,947                                     1,413    1,356    1,470
# 1577      12,683                                       951      950      952
# 1578       5,000                                       509      509      509
# 1579      12,617                                       917      901      933
# 1580       1,457                                        52       50       54
#
#      Percentage of Staffed Adult ICU Beds Occupied Estimated Percentage LL  \
# 0                                                 88.53              88.53
# 1                                                 81.10              81.10
# 2                                                 69.83              69.83
# 3                                                 80.99              80.99
# 4                                                 79.70              79.70
# ...                                                 ...                ...
# 1576                                              72.54              63.50
# 1577                                              70.50              69.96
# 1578                                              83.17              83.17
# 1579                                              56.71              53.15
# 1580                                              40.94              36.26
#
#      Percentage UL  Total Staffed Adult ICU Beds  Total LL  Total UL
# 0            88.53                         1,482     1,482     1,482
# 1            81.10                           127       127       127
# 2            69.83                         1,989     1,989     1,989
# 3            80.99                         1,015     1,015     1,015
# 4            79.70                         7,369     7,365     7,373
# ...            ...                           ...       ...       ...
# 1576         81.57                         1,948     1,881     2,015
# 1577         71.03                         1,349     1,345     1,353
# 1578         83.17                           612       596       628
# 1579         60.27                         1,617     1,591     1,643
# 1580         45.63                           127       124       130
#
# [1581 rows x 32 columns]

# %% [markdown]
# ## Changing LL and UL column names

# %%
final_dataset.rename(columns = {'Count LL_x':'Count LL_inpatient beds occupied'}, inplace = True) 
final_dataset.rename(columns = {'Count UL_x':'Count UL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage LL_x':'Percentage LL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage UL_x':'Percentage UL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Total LL_x':'Total LL_inpatient beds occupied'}, inplace = True)
final_dataset.rename(columns = {'Total UL_x':'Total UL_inpatient beds occupied'}, inplace = True)

# %%
final_dataset.rename(columns = {'Count LL_y':'Count LL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Count UL_y':'Count UL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Percentage LL_y':'Percentage LL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Percentage UL_y':'Percentage UL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Total LL_y':'Total LL_occupied by COVID-19 patients'}, inplace = True)
final_dataset.rename(columns = {'Total UL_y':'Total UL_occupied by COVID-19 patients'}, inplace = True)

# %%
final_dataset.rename(columns = {'Count LL':'Count LL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Count UL':'Count UL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage LL':'Percentage LL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Percentage UL':'Percentage UL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Total LL':'Total LL_ICU Beds Occupied'}, inplace = True)
final_dataset.rename(columns = {'Total UL':'Total UL_ICU Beds Occupied'}, inplace = True)

# %% [markdown]
# ## Final dataset column names

# %%
# list of columns in final dataset
list(final_dataset.columns)
# Out:
# ['date',
#  'state',
#  'fips',
#  'cases',
#  'deaths',
#  'Inpatient Beds Occupied Estimated',
#  'Count LL_inpatient beds occupied',
#  'Count UL_inpatient beds occupied',
#  'Percentage of Inpatient Beds Occupied Estimated',
#  'Percentage LL_inpatient beds occupied',
#  'Percentage UL_inpatient beds occupied',
#  'Total Inpatient Beds_x',
#  'Total LL_inpatient beds occupied',
#  'Total UL_inpatient beds occupied',
#  'Inpatient Beds Occupied by COVID-19 Patients Estimated',
#  'Count LL_occupied by COVID-19 patients',
#  'Count UL_occupied by COVID-19 patients',
#  'Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated',
#  'Percentage LL_occupied by COVID-19 patients',
#  'Percentage UL_occupied by COVID-19 patients',
#  'Total Inpatient Beds_y',
#  'Total LL_occupied by COVID-19 patients',
#  'Total UL_occupied by COVID-19 patients',
#  'Staffed Adult ICU Beds Occupied Estimated',
#  'Count LL_ICU Beds Occupied',
#  'Count UL_ICU Beds Occupied',
#  'Percentage of Staffed Adult ICU Beds Occupied Estimated',
#  'Percentage LL_ICU Beds Occupied',
#  'Percentage UL_ICU Beds Occupied',
#  'Total Staffed Adult ICU Beds',
#  'Total LL_ICU Beds Occupied',
#  'Total UL_ICU Beds Occupied']

# %% [markdown]
# ## Checking the final dataset

# %%
final_dataset
# Out:
#             date state  fips    cases  deaths  \
# 0     2020-12-02    AL     1   256828    3711
# 1     2020-12-02    AK     2    33614     116
# 2     2020-12-02    AZ     4   342925    6755
# 3     2020-12-02    AR     5   161521    2522
# 4     2020-12-02    CA     6  1272041   19440
# ...          ...   ...   ...      ...     ...
# 1576  2021-01-01    VA    51   354766    5081
# 1577  2021-01-01    WA    53   251585    3523
# 1578  2021-01-01    WV    54    87820    1361
# 1579  2021-01-01    WI    55   522523    5257
# 1580  2021-01-01    WY    56    44409     438
#
#      Inpatient Beds Occupied Estimated Count LL_inpatient beds occupied  \
# 0                               11,036                           11,036
# 1                                  933                              933
# 2                               10,620                           10,613
# 3                                5,531                            5,531
# 4                               47,713                           47,665
# ...                                ...                              ...
# 1576                            11,402                           10,991
# 1577                             8,450                            8,331
# 1578                             3,745                            3,745
# 1579                             7,484                            7,365
# 1580                               576                              567
#
#      Count UL_inpatient beds occupied  \
# 0                              11,036
# 1                                 933
# 2                              10,627
# 3                               5,531
# 4                              47,761
# ...                               ...
# 1576                           11,813
# 1577                            8,569
# 1578                            3,745
# 1579                            7,603
# 1580                              585
#
#       Percentage of Inpatient Beds Occupied Estimated  \
# 0                                               77.89
# 1                                               65.02
# 2                                               76.94
# 3                                               73.53
# 4                                               75.98
# ...                                               ...
# 1576                                            69.44
# 1577                                            67.61
# 1578                                            74.90
# 1579                                            60.08
# 1580                                            40.06
#
#       Percentage LL_inpatient beds occupied  ...  \
# 0                                     77.89  ...
# 1                                     65.02  ...
# 2                                     76.75  ...
# 3                                     73.53  ...
# 4                                     75.91  ...
# ...                                     ...  ...
# 1576                                  61.40  ...
# 1577                                  64.25  ...
# 1578                                  74.90  ...
# 1579                                  56.91  ...
# 1580                                  37.48  ...
#
#       Total UL_occupied by COVID-19 patients  \
# 0                                     14,168
# 1                                      1,435
# 2                                     13,815
# 3                                      7,522
# 4                                     62,919
# ...                                      ...
# 1576                                  16,947
# 1577                                  12,683
# 1578                                   5,000
# 1579                                  12,617
# 1580                                   1,457
#
#      Staffed Adult ICU Beds Occupied Estimated Count LL_ICU Beds Occupied  \
# 0                                        1,312                      1,312
# 1                                          103                        103
# 2                                        1,389                      1,389
# 3                                          822                        822
# 4                                        5,862                      5,855
# ...                                        ...                        ...
# 1576                                     1,413                      1,356
# 1577                                       951                        950
# 1578                                       509                        509
# 1579                                       917                        901
# 1580                                        52                         50
#
#      Count UL_ICU Beds Occupied  \
# 0                         1,312
# 1                           103
# 2                         1,389
# 3                           822
# 4                         5,869
# ...                         ...
# 1576                      1,470
# 1577                        952
# 1578                        509
# 1579                        933
# 1580                         54
#
#      Percentage of Staffed Adult ICU Beds Occupied Estimated  \
# 0                                                 88.53
# 1                                                 81.10
# 2                                                 69.83
# 3                                                 80.99
# 4                                                 79.70
# ...                                                 ...
# 1576                                              72.54
# 1577                                              70.50
# 1578                                              83.17
# 1579                                              56.71
# 1580                                              40.94
#
#      Percentage LL_ICU Beds Occupied Percentage UL_ICU Beds Occupied  \
# 0                              88.53                           88.53
# 1                              81.10                           81.10
# 2                              69.83                           69.83
# 3                              80.99                           80.99
# 4                              79.70                           79.70
# ...                              ...                             ...
# 1576                           63.50                           81.57
# 1577                           69.96                           71.03
# 1578                           83.17                           83.17
# 1579                           53.15                           60.27
# 1580                           36.26                           45.63
#
#       Total Staffed Adult ICU Beds  Total LL_ICU Beds Occupied  \
# 0                            1,482                       1,482
# 1                              127                         127
# 2                            1,989                       1,989
# 3                            1,015                       1,015
# 4                            7,369                       7,365
# ...                            ...                         ...
# 1576                         1,948                       1,881
# 1577                         1,349                       1,345
# 1578                           612                         596
# 1579                         1,617                       1,591
# 1580                           127                         124
#
#       Total UL_ICU Beds Occupied
# 0                          1,482
# 1                            127
# 2                          1,989
# 3                          1,015
# 4                          7,373
# ...                          ...
# 1576                       2,015
# 1577                       1,353
# 1578                         628
# 1579                       1,643
# 1580                         130
#
# [1581 rows x 32 columns]

# %% [markdown]
# ### Export of the files

# %%
 final_dataset.to_csv('final_covid.csv')
# fnl_covid.to_json('file.json', orient = 'split', compression = 'infer', index = 'true') 
# https://towardsdatascience.com/automatically-update-data-sources-in-python-e424dbea68d0

# %% [markdown]
# ### Reference:
# * Data Import (https://www.datacamp.com/community/tutorials/importing-data-into-pandas)
# * Remapping (https://gist.github.com/rogerallen/1583593)
# * Pandas Indexing (https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/)
# * https://www.geeksforgeeks.org/using-dictionary-to-remap-values-in-pandas-dataframe-columns/
# * NYT data (https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv)
# * Healthdata.gov data (https://healthdata.gov/dataset/covid-19-estimated-patient-impact-and-hospital-capacity-state)

# %% [markdown]
# ### Working with API json file

# %%
df = pd.read_json('https://healthdata.gov/api/action/datastore/search.json?resource_id=2e53c415-5cbe-440a-824e-aa3e450c8fa1&limit=100&offset=100')
df.head()
# Out:
#                                                           help  success  \
# fields       Search a datastore table. :param resource_id: ...     True
# limit        Search a datastore table. :param resource_id: ...     True
# records      Search a datastore table. :param resource_id: ...     True
# resource_id  Search a datastore table. :param resource_id: ...     True
# total        Search a datastore table. :param resource_id: ...     True
#
#                                                         result
# fields       [{'id': 'state', 'type': 'text'}, {'id': 'coll...
# limit                                                      100
# records      [{'state': 'AK', 'collection_date': '2020-07-0...
# resource_id             [2e53c415-5cbe-440a-824e-aa3e450c8fa1]
# total                                                     1232

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, fields to total
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   help     5 non-null      object
#  1   success  5 non-null      bool
#  2   result   5 non-null      object
# dtypes: bool(1), object(2)
# memory usage: 125.0+ bytes

# %%
df.result[2]
# Out:
# [{'state': 'AK',
#   'collection_date': '2020-07-03',
#   'inpatient_beds_occupied_estimated': '882.3477386934674',
#   'count_ll': '860.4698240983954',
#   'count_ul': '904.2256532885394',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.570877531340405',
#   'percentage_ll': '0.5278614915699119',
#   'percentage_ul': '0.613893571110898',
#   'entry_id': '501'},
#  {'state': 'AK',
#   'collection_date': '2020-07-04',
#   'inpatient_beds_occupied_estimated': '886.819095477387',
#   'count_ll': '864.959874454702',
#   'count_ul': '908.678316500072',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5737704918032787',
#   'percentage_ll': '0.5307912070648869',
#   'percentage_ul': '0.6167497765416704',
#   'entry_id': '506'},
#  {'state': 'AK',
#   'collection_date': '2020-07-05',
#   'inpatient_beds_occupied_estimated': '912.9869706840393',
#   'count_ll': '890.152777851274',
#   'count_ul': '935.8211635168045',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6077170418006431',
#   'percentage_ll': '0.5676093808306408',
#   'percentage_ul': '0.6478247027706454',
#   'entry_id': '511'},
#  {'state': 'AK',
#   'collection_date': '2020-07-06',
#   'inpatient_beds_occupied_estimated': '912.1567839195982',
#   'count_ll': '890.4180002929129',
#   'count_ul': '933.8955675462835',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5901639344262295',
#   'percentage_ll': '0.5474214519567956',
#   'percentage_ul': '0.6329064168956634',
#   'entry_id': '516'},
#  {'state': 'AK',
#   'collection_date': '2020-07-07',
#   'inpatient_beds_occupied_estimated': '940.4753768844223',
#   'count_ll': '918.9007765019992',
#   'count_ul': '962.0499772668452',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6084860173577628',
#   'percentage_ll': '0.5660663496124719',
#   'percentage_ul': '0.6509056851030536',
#   'entry_id': '521'},
#  {'state': 'AK',
#   'collection_date': '2020-07-08',
#   'inpatient_beds_occupied_estimated': '908.7744107744106',
#   'count_ll': '878.8572541311352',
#   'count_ul': '938.6915674176861',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5723270440251572',
#   'percentage_ll': '0.5408967905318929',
#   'percentage_ul': '0.6037572975184216',
#   'entry_id': '526'},
#  {'state': 'AK',
#   'collection_date': '2020-07-09',
#   'inpatient_beds_occupied_estimated': '841.3653198653199',
#   'count_ll': '811.1841745675222',
#   'count_ul': '871.5464651631174',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.529874213836478',
#   'percentage_ll': '0.49816662013906554',
#   'percentage_ul': '0.5615818075338905',
#   'entry_id': '531'},
#  {'state': 'AK',
#   'collection_date': '2020-07-10',
#   'inpatient_beds_occupied_estimated': '820.438045375218',
#   'count_ll': '789.7465465435776',
#   'count_ul': '851.1295442068587',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5129449838187702',
#   'percentage_ll': '0.481673905845638',
#   'percentage_ul': '0.5442160617919023',
#   'entry_id': '536'},
#  {'state': 'AK',
#   'collection_date': '2020-07-11',
#   'inpatient_beds_occupied_estimated': '716.1994750656168',
#   'count_ll': '682.3053327565149',
#   'count_ul': '750.0936173747185',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4380952380952381',
#   'percentage_ll': '0.4101943042525111',
#   'percentage_ul': '0.4659961719379651',
#   'entry_id': '541'},
#  {'state': 'AK',
#   'collection_date': '2020-07-12',
#   'inpatient_beds_occupied_estimated': '688.9527559055117',
#   'count_ll': '655.2201800568484',
#   'count_ul': '722.6853317541751',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.42142857142857143',
#   'percentage_ll': '0.39366063564441117',
#   'percentage_ul': '0.4491965072127317',
#   'entry_id': '546'},
#  {'state': 'AK',
#   'collection_date': '2020-07-13',
#   'inpatient_beds_occupied_estimated': '650.1822660098521',
#   'count_ll': '617.1919456740011',
#   'count_ul': '683.1725863457033',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4',
#   'percentage_ll': '0.372052893375574',
#   'percentage_ul': '0.42794710662442603',
#   'entry_id': '551'},
#  {'state': 'AK',
#   'collection_date': '2020-07-14',
#   'inpatient_beds_occupied_estimated': '759.7635467980296',
#   'count_ll': '726.164516668672',
#   'count_ul': '793.3625769273871',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.46741573033707867',
#   'percentage_ll': '0.43895296707975934',
#   'percentage_ul': '0.495878493594398',
#   'entry_id': '556'},
#  {'state': 'AL',
#   'collection_date': '2020-03-02',
#   'inpatient_beds_occupied_estimated': '3785.2816901408446',
#   'count_ll': '3682.3045359672606',
#   'count_ul': '3888.258844314429',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.26785714285714285',
#   'percentage_ll': '0.2605411997623272',
#   'percentage_ul': '0.2751730859519585',
#   'entry_id': '561'},
#  {'state': 'AL',
#   'collection_date': '2020-03-03',
#   'inpatient_beds_occupied_estimated': '4794.69014084507',
#   'count_ll': '4684.591745236901',
#   'count_ul': '4904.788536453239',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.3392857142857143',
#   'percentage_ll': '0.331463847352568',
#   'percentage_ul': '0.3471075812188606',
#   'entry_id': '566'},
#  {'state': 'AL',
#   'collection_date': '2020-03-04',
#   'inpatient_beds_occupied_estimated': '4794.69014084507',
#   'count_ll': '4684.591745236901',
#   'count_ul': '4904.788536453239',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.3392857142857143',
#   'percentage_ll': '0.331463847352568',
#   'percentage_ul': '0.3471075812188606',
#   'entry_id': '571'},
#  {'state': 'AL',
#   'collection_date': '2020-03-05',
#   'inpatient_beds_occupied_estimated': '4037.633802816901',
#   'count_ll': '3932.5844660511243',
#   'count_ul': '4142.6831395826775',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2857142857142857',
#   'percentage_ll': '0.27825112579212413',
#   'percentage_ul': '0.29317744563644726',
#   'entry_id': '576'},
#  {'state': 'AL',
#   'collection_date': '2020-03-06',
#   'inpatient_beds_occupied_estimated': '4166.7441860465115',
#   'count_ll': '4059.773296514186',
#   'count_ul': '4273.715075578838',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.28169014084507044',
#   'percentage_ll': '0.274423561671926',
#   'percentage_ul': '0.2889567200182149',
#   'entry_id': '581'},
#  {'state': 'AL',
#   'collection_date': '2020-03-07',
#   'inpatient_beds_occupied_estimated': '3583.4',
#   'count_ll': '3478.5020890961123',
#   'count_ul': '3688.2979109038884',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2',
#   'percentage_ll': '0.19414043621361368',
#   'percentage_ul': '0.20585956378638634',
#   'entry_id': '586'},
#  {'state': 'AL',
#   'collection_date': '2020-03-08',
#   'inpatient_beds_occupied_estimated': '3583.4',
#   'count_ll': '3478.5020890961123',
#   'count_ul': '3688.2979109038884',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2',
#   'percentage_ll': '0.19414043621361368',
#   'percentage_ul': '0.20585956378638634',
#   'entry_id': '591'},
#  {'state': 'AL',
#   'collection_date': '2020-03-09',
#   'inpatient_beds_occupied_estimated': '3750.06976744186',
#   'count_ll': '3646.6175726860047',
#   'count_ul': '3853.5219621977158',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2535211267605634',
#   'percentage_ll': '0.24649357405799555',
#   'percentage_ul': '0.2605486794631312',
#   'entry_id': '596'},
#  {'state': 'AL',
#   'collection_date': '2020-03-10',
#   'inpatient_beds_occupied_estimated': '5000.093023255814',
#   'count_ll': '4887.60142913902',
#   'count_ul': '5112.584617372608',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.3380281690140845',
#   'percentage_ll': '0.33038656597108196',
#   'percentage_ul': '0.34566977205708704',
#   'entry_id': '601'},
#  {'state': 'AL',
#   'collection_date': '2020-03-11',
#   'inpatient_beds_occupied_estimated': '4166.7441860465115',
#   'count_ll': '4059.773296514186',
#   'count_ul': '4273.715075578838',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.28169014084507044',
#   'percentage_ll': '0.274423561671926',
#   'percentage_ul': '0.2889567200182149',
#   'entry_id': '606'},
#  {'state': 'AL',
#   'collection_date': '2020-03-12',
#   'inpatient_beds_occupied_estimated': '3125.0581395348836',
#   'count_ll': '3027.9836390657265',
#   'count_ul': '3222.1326400040407',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2112676056338028',
#   'percentage_ll': '0.20467329248527646',
#   'percentage_ul': '0.21786191878232916',
#   'entry_id': '611'},
#  {'state': 'AL',
#   'collection_date': '2020-03-13',
#   'inpatient_beds_occupied_estimated': '3203.701986754967',
#   'count_ll': '3111.276163271362',
#   'count_ul': '3296.1278102385722',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.3',
#   'percentage_ll': '0.29127153029755687',
#   'percentage_ul': '0.3087284697024431',
#   'entry_id': '616'},
#  {'state': 'AL',
#   'collection_date': '2020-03-14',
#   'inpatient_beds_occupied_estimated': '3559.6688741721855',
#   'count_ll': '3464.591446262017',
#   'count_ul': '3654.746302082354',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.3333333333333333',
#   'percentage_ll': '0.3243544525658027',
#   'percentage_ul': '0.34231221410086393',
#   'entry_id': '621'},
#  {'state': 'AL',
#   'collection_date': '2020-03-15',
#   'inpatient_beds_occupied_estimated': '4375.081395348837',
#   'count_ll': '4266.548804383402',
#   'count_ul': '4483.613986314273',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.29577464788732394',
#   'percentage_ll': '0.2884019816548111',
#   'percentage_ul': '0.30314731411983675',
#   'entry_id': '626'},
#  {'state': 'AL',
#   'collection_date': '2020-03-16',
#   'inpatient_beds_occupied_estimated': '3750.06976744186',
#   'count_ll': '3646.6175726860047',
#   'count_ul': '3853.5219621977158',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2535211267605634',
#   'percentage_ll': '0.24649357405799555',
#   'percentage_ul': '0.2605486794631312',
#   'entry_id': '631'},
#  {'state': 'AL',
#   'collection_date': '2020-03-17',
#   'inpatient_beds_occupied_estimated': '4583.418604651162',
#   'count_ll': '4473.448433287675',
#   'count_ul': '4693.388776014651',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.30985915492957744',
#   'percentage_ll': '0.3023888332337336',
#   'percentage_ul': '0.31732947662542127',
#   'entry_id': '636'},
#  {'state': 'AL',
#   'collection_date': '2020-03-18',
#   'inpatient_beds_occupied_estimated': '3541.732558139535',
#   'count_ll': '3440.2510618626106',
#   'count_ul': '3643.214054416459',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.23943661971830985',
#   'percentage_ll': '0.232542937422786',
#   'percentage_ul': '0.24633030201383369',
#   'entry_id': '641'},
#  {'state': 'AL',
#   'collection_date': '2020-03-19',
#   'inpatient_beds_occupied_estimated': '3958.4069767441856',
#   'count_ll': '3853.1274331152613',
#   'count_ul': '4063.6865203731104',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2676056338028169',
#   'percentage_ll': '0.2604539484944423',
#   'percentage_ul': '0.27475731911119144',
#   'entry_id': '646'},
#  {'state': 'AL',
#   'collection_date': '2020-03-20',
#   'inpatient_beds_occupied_estimated': '3125.0581395348836',
#   'count_ll': '3027.9836390657265',
#   'count_ul': '3222.1326400040407',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2112676056338028',
#   'percentage_ll': '0.20467329248527646',
#   'percentage_ul': '0.21786191878232916',
#   'entry_id': '651'},
#  {'state': 'AL',
#   'collection_date': '2020-03-21',
#   'inpatient_beds_occupied_estimated': '3333.3953488372094',
#   'count_ll': '3234.036429926453',
#   'count_ul': '3432.754267747966',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.22535211267605634',
#   'percentage_ll': '0.21860261798661687',
#   'percentage_ul': '0.23210160736549582',
#   'entry_id': '656'},
#  {'state': 'AL',
#   'collection_date': '2020-03-22',
#   'inpatient_beds_occupied_estimated': '3958.4069767441856',
#   'count_ll': '3853.1274331152613',
#   'count_ul': '4063.6865203731104',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2676056338028169',
#   'percentage_ll': '0.2604539484944423',
#   'percentage_ul': '0.27475731911119144',
#   'entry_id': '661'},
#  {'state': 'AL',
#   'collection_date': '2020-03-23',
#   'inpatient_beds_occupied_estimated': '4166.7441860465115',
#   'count_ll': '4059.773296514186',
#   'count_ul': '4273.715075578838',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.28169014084507044',
#   'percentage_ll': '0.274423561671926',
#   'percentage_ul': '0.2889567200182149',
#   'entry_id': '666'},
#  {'state': 'AL',
#   'collection_date': '2020-03-24',
#   'inpatient_beds_occupied_estimated': '3750.06976744186',
#   'count_ll': '3646.6175726860047',
#   'count_ul': '3853.5219621977158',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2535211267605634',
#   'percentage_ll': '0.24649357405799555',
#   'percentage_ul': '0.2605486794631312',
#   'entry_id': '671'},
#  {'state': 'AL',
#   'collection_date': '2020-03-25',
#   'inpatient_beds_occupied_estimated': '3750.06976744186',
#   'count_ll': '3646.6175726860047',
#   'count_ul': '3853.5219621977158',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.2535211267605634',
#   'percentage_ll': '0.24649357405799555',
#   'percentage_ul': '0.2605486794631312',
#   'entry_id': '676'},
#  {'state': 'AL',
#   'collection_date': '2020-03-26',
#   'inpatient_beds_occupied_estimated': '3541.732558139535',
#   'count_ll': '3440.2510618626106',
#   'count_ul': '3643.214054416459',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.23943661971830985',
#   'percentage_ll': '0.232542937422786',
#   'percentage_ul': '0.24633030201383369',
#   'entry_id': '681'},
#  {'state': 'AL',
#   'collection_date': '2020-03-27',
#   'inpatient_beds_occupied_estimated': '6073.928311057109',
#   'count_ll': '5963.94455633407',
#   'count_ul': '6183.912065780148',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.45662847790507366',
#   'percentage_ll': '0.4479619833743924',
#   'percentage_ul': '0.4652949724357549',
#   'entry_id': '686'},
#  {'state': 'AL',
#   'collection_date': '2020-03-28',
#   'inpatient_beds_occupied_estimated': '5420.817739975699',
#   'count_ll': '5312.444943242125',
#   'count_ul': '5529.190536709272',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4088669950738916',
#   'percentage_ll': '0.4002993962187127',
#   'percentage_ul': '0.41743459392907056',
#   'entry_id': '691'},
#  {'state': 'AL',
#   'collection_date': '2020-03-29',
#   'inpatient_beds_occupied_estimated': '5230.009416195857',
#   'count_ll': '5124.462495352707',
#   'count_ul': '5335.5563370390055',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4105960264900662',
#   'percentage_ll': '0.40178768027759765',
#   'percentage_ul': '0.4194043727025348',
#   'entry_id': '696'},
#  {'state': 'AL',
#   'collection_date': '2020-03-30',
#   'inpatient_beds_occupied_estimated': '5824.838461538462',
#   'count_ll': '5721.352199993294',
#   'count_ul': '5928.3247230836305',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4448753462603878',
#   'percentage_ll': '0.4357076904724325',
#   'percentage_ul': '0.45404300204834314',
#   'entry_id': '701'},
#  {'state': 'AL',
#   'collection_date': '2020-03-31',
#   'inpatient_beds_occupied_estimated': '5277.875968992248',
#   'count_ll': '5185.910836103586',
#   'count_ul': '5369.841101880911',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4528710725893825',
#   'percentage_ll': '0.44252076639380056',
#   'percentage_ul': '0.4632213787849644',
#   'entry_id': '706'},
#  {'state': 'AL',
#   'collection_date': '2020-04-01',
#   'inpatient_beds_occupied_estimated': '5665.505788712011',
#   'count_ll': '5576.283046395731',
#   'count_ul': '5754.728531028291',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.47103206682834814',
#   'percentage_ll': '0.46030412538090276',
#   'percentage_ul': '0.4817600082757935',
#   'entry_id': '711'},
#  {'state': 'AL',
#   'collection_date': '2020-04-02',
#   'inpatient_beds_occupied_estimated': '5477.2011361619025',
#   'count_ll': '5389.476109545734',
#   'count_ul': '5564.926162778071',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.46654023299918723',
#   'percentage_ll': '0.4556414148338312',
#   'percentage_ul': '0.47743905116454327',
#   'entry_id': '716'},
#  {'state': 'AL',
#   'collection_date': '2020-04-03',
#   'inpatient_beds_occupied_estimated': '5419.688398177357',
#   'count_ll': '5331.63702908318',
#   'count_ul': '5507.739767271534',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4536136662286465',
#   'percentage_ll': '0.4428002732063845',
#   'percentage_ul': '0.46442705925090855',
#   'entry_id': '721'},
#  {'state': 'AL',
#   'collection_date': '2020-04-04',
#   'inpatient_beds_occupied_estimated': '5648.866376754299',
#   'count_ll': '5556.569731692231',
#   'count_ul': '5741.163021816368',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4529963078670832',
#   'percentage_ll': '0.44268268734880883',
#   'percentage_ul': '0.4633099283853576',
#   'entry_id': '726'},
#  {'state': 'AL',
#   'collection_date': '2020-04-05',
#   'inpatient_beds_occupied_estimated': '5556.784542399684',
#   'count_ll': '5464.616925173671',
#   'count_ul': '5648.952159625696',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4454855195911414',
#   'percentage_ll': '0.43518924144149496',
#   'percentage_ul': '0.45578179774078786',
#   'entry_id': '731'},
#  {'state': 'AL',
#   'collection_date': '2020-04-06',
#   'inpatient_beds_occupied_estimated': '5559.214415395787',
#   'count_ll': '5469.551508241906',
#   'count_ul': '5648.877322549669',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4564636752136752',
#   'percentage_ll': '0.4458336542033788',
#   'percentage_ul': '0.4670936962239716',
#   'entry_id': '736'},
#  {'state': 'AL',
#   'collection_date': '2020-04-07',
#   'inpatient_beds_occupied_estimated': '6355.289634560521',
#   'count_ll': '6269.690748533949',
#   'count_ul': '6440.888520587095',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.49060503570086433',
#   'percentage_ll': '0.4793892247904591',
#   'percentage_ul': '0.5018208466112696',
#   'entry_id': '741'},
#  {'state': 'AL',
#   'collection_date': '2020-04-08',
#   'inpatient_beds_occupied_estimated': '7184.0812952118495',
#   'count_ll': '7101.713107865975',
#   'count_ul': '7266.449482557724',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5216611891245891',
#   'percentage_ll': '0.5100232312571364',
#   'percentage_ul': '0.5332991469920418',
#   'entry_id': '746'},
#  {'state': 'AL',
#   'collection_date': '2020-04-09',
#   'inpatient_beds_occupied_estimated': '7208.768859800208',
#   'count_ll': '7126.299525161587',
#   'count_ul': '7291.238194438827',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5221278497988378',
#   'percentage_ll': '0.510505117585653',
#   'percentage_ul': '0.5337505820120225',
#   'entry_id': '751'},
#  {'state': 'AL',
#   'collection_date': '2020-04-10',
#   'inpatient_beds_occupied_estimated': '7453.384493284494',
#   'count_ll': '7367.688260901086',
#   'count_ul': '7539.080725667902',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.527562712914215',
#   'percentage_ll': '0.5163897418538153',
#   'percentage_ul': '0.5387356839746147',
#   'entry_id': '756'},
#  {'state': 'AL',
#   'collection_date': '2020-04-11',
#   'inpatient_beds_occupied_estimated': '6826.3264346190035',
#   'count_ll': '6738.868319974904',
#   'count_ul': '6913.784549263104',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.501149018914619',
#   'percentage_ll': '0.49016782029106004',
#   'percentage_ul': '0.5121302175381781',
#   'entry_id': '761'},
#  {'state': 'AL',
#   'collection_date': '2020-04-12',
#   'inpatient_beds_occupied_estimated': '6872.942650865005',
#   'count_ll': '6784.9674240264285',
#   'count_ul': '6960.91787770358',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5033964962459778',
#   'percentage_ll': '0.4924802904333219',
#   'percentage_ul': '0.5143127020586338',
#   'entry_id': '766'},
#  {'state': 'AL',
#   'collection_date': '2020-04-13',
#   'inpatient_beds_occupied_estimated': '6679.732617781155',
#   'count_ll': '6606.374591355327',
#   'count_ul': '6753.090644206983',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.4914850989231154',
#   'percentage_ll': '0.4783969405145715',
#   'percentage_ul': '0.5045732573316594',
#   'entry_id': '771'},
#  {'state': 'AL',
#   'collection_date': '2020-04-14',
#   'inpatient_beds_occupied_estimated': '7290.957611500184',
#   'count_ll': '7219.240247113834',
#   'count_ul': '7362.674975886534',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5343012704174228',
#   'percentage_ll': '0.5209728377652902',
#   'percentage_ul': '0.5476297030695554',
#   'entry_id': '776'},
#  {'state': 'AL',
#   'collection_date': '2020-04-15',
#   'inpatient_beds_occupied_estimated': '7396.193533401469',
#   'count_ll': '7324.143638128695',
#   'count_ul': '7468.243428674243',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5424246123794408',
#   'percentage_ll': '0.5291909261772705',
#   'percentage_ul': '0.5556582985816112',
#   'entry_id': '781'},
#  {'state': 'AL',
#   'collection_date': '2020-04-16',
#   'inpatient_beds_occupied_estimated': '7624.393615091601',
#   'count_ll': '7554.328142101984',
#   'count_ul': '7694.4590880812175',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5642135642135642',
#   'percentage_ll': '0.5507324646639234',
#   'percentage_ul': '0.5776946637632049',
#   'entry_id': '786'},
#  {'state': 'AL',
#   'collection_date': '2020-04-17',
#   'inpatient_beds_occupied_estimated': '7645.0234003656315',
#   'count_ll': '7573.987543167648',
#   'count_ul': '7716.059257563614',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.558774239885085',
#   'percentage_ll': '0.545441120936301',
#   'percentage_ul': '0.572107358833869',
#   'entry_id': '791'},
#  {'state': 'AL',
#   'collection_date': '2020-04-18',
#   'inpatient_beds_occupied_estimated': '7370.31967545639',
#   'count_ll': '7293.2602046278835',
#   'count_ul': '7447.379146284896',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.533613998158137',
#   'percentage_ll': '0.5212072250187635',
#   'percentage_ul': '0.5460207712975106',
#   'entry_id': '796'},
#  {'state': 'AL',
#   'collection_date': '2020-04-19',
#   'inpatient_beds_occupied_estimated': '7460.521311475411',
#   'count_ll': '7383.475645159812',
#   'count_ul': '7537.566977791009',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5450643776824035',
#   'percentage_ll': '0.5327003015255559',
#   'percentage_ul': '0.557428453839251',
#   'entry_id': '801'},
#  {'state': 'AL',
#   'collection_date': '2020-04-20',
#   'inpatient_beds_occupied_estimated': '7340.490478938257',
#   'count_ll': '7275.200255707699',
#   'count_ul': '7405.780702168815',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5318921232876712',
#   'percentage_ll': '0.51724226252148',
#   'percentage_ul': '0.5465419840538625',
#   'entry_id': '806'},
#  {'state': 'AL',
#   'collection_date': '2020-04-21',
#   'inpatient_beds_occupied_estimated': '7714.868376068376',
#   'count_ll': '7644.059741225586',
#   'count_ul': '7785.677010911166',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5543843391636742',
#   'percentage_ll': '0.5409814841377693',
#   'percentage_ul': '0.5677871941895792',
#   'entry_id': '811'},
#  {'state': 'AL',
#   'collection_date': '2020-04-22',
#   'inpatient_beds_occupied_estimated': '7934.99278091651',
#   'count_ll': '7858.431463486885',
#   'count_ul': '8011.554098346135',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5878350229134842',
#   'percentage_ll': '0.5756779425384144',
#   'percentage_ul': '0.599992103288554',
#   'entry_id': '816'},
#  {'state': 'AL',
#   'collection_date': '2020-04-23',
#   'inpatient_beds_occupied_estimated': '8255.503154399557',
#   'count_ll': '8176.213237280304',
#   'count_ul': '8334.79307151881',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6001153236269281',
#   'percentage_ll': '0.588488431117091',
#   'percentage_ul': '0.6117422161367652',
#   'entry_id': '821'},
#  {'state': 'AL',
#   'collection_date': '2020-04-24',
#   'inpatient_beds_occupied_estimated': '8161.866234467856',
#   'count_ll': '8083.813740823916',
#   'count_ul': '8239.918728111796',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.59809902113775',
#   'percentage_ll': '0.5862681284333763',
#   'percentage_ul': '0.6099299138421238',
#   'entry_id': '826'},
#  {'state': 'AL',
#   'collection_date': '2020-04-25',
#   'inpatient_beds_occupied_estimated': '7917.482466192986',
#   'count_ll': '7836.753412375595',
#   'count_ul': '7998.211520010377',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5823014195107218',
#   'percentage_ll': '0.5707271623214035',
#   'percentage_ul': '0.59387567670004',
#   'entry_id': '831'},
#  {'state': 'AL',
#   'collection_date': '2020-04-26',
#   'inpatient_beds_occupied_estimated': '7599.222667889067',
#   'count_ll': '7518.797082778547',
#   'count_ul': '7679.648252999589',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5680736761320031',
#   'percentage_ll': '0.5563535509156717',
#   'percentage_ul': '0.5797938013483345',
#   'entry_id': '836'},
#  {'state': 'AL',
#   'collection_date': '2020-04-27',
#   'inpatient_beds_occupied_estimated': '7703.7203825586175',
#   'count_ll': '7628.515234914081',
#   'count_ul': '7778.925530203154',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5820687734929695',
#   'percentage_ll': '0.5696424201932453',
#   'percentage_ul': '0.5944951267926937',
#   'entry_id': '841'},
#  {'state': 'AL',
#   'collection_date': '2020-04-28',
#   'inpatient_beds_occupied_estimated': '7864.0226244343885',
#   'count_ll': '7788.928091079923',
#   'count_ul': '7939.1171577888545',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5917914586799778',
#   'percentage_ll': '0.5794332763007106',
#   'percentage_ul': '0.6041496410592451',
#   'entry_id': '846'},
#  {'state': 'AL',
#   'collection_date': '2020-04-29',
#   'inpatient_beds_occupied_estimated': '8216.81953488372',
#   'count_ll': '8141.613259725282',
#   'count_ul': '8292.02581004216',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.610484314804623',
#   'percentage_ll': '0.5983376366536196',
#   'percentage_ul': '0.6226309929556263',
#   'entry_id': '851'},
#  {'state': 'AL',
#   'collection_date': '2020-04-30',
#   'inpatient_beds_occupied_estimated': '8363.973454192295',
#   'count_ll': '8287.075151033523',
#   'count_ul': '8440.871757351066',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6187955943355743',
#   'percentage_ll': '0.6070113833331154',
#   'percentage_ul': '0.6305798053380332',
#   'entry_id': '856'},
#  {'state': 'AL',
#   'collection_date': '2020-05-01',
#   'inpatient_beds_occupied_estimated': '8354.397271087055',
#   'count_ll': '8275.042373889159',
#   'count_ul': '8433.75216828495',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.611505471753919',
#   'percentage_ll': '0.6000047879525853',
#   'percentage_ul': '0.6230061555552527',
#   'entry_id': '861'},
#  {'state': 'AL',
#   'collection_date': '2020-05-02',
#   'inpatient_beds_occupied_estimated': '7827.79438229572',
#   'count_ll': '7744.976473292106',
#   'count_ul': '7910.612291299334',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5783966516419833',
#   'percentage_ll': '0.5670852166726866',
#   'percentage_ul': '0.5897080866112799',
#   'entry_id': '866'},
#  {'state': 'AL',
#   'collection_date': '2020-05-03',
#   'inpatient_beds_occupied_estimated': '6792.081930097637',
#   'count_ll': '6705.465723584053',
#   'count_ul': '6878.69813661122',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5251911389923545',
#   'percentage_ll': '0.5141312902154093',
#   'percentage_ul': '0.5362509877692997',
#   'entry_id': '871'},
#  {'state': 'AL',
#   'collection_date': '2020-05-04',
#   'inpatient_beds_occupied_estimated': '8173.70917200366',
#   'count_ll': '8093.315358834814',
#   'count_ul': '8254.102985172505',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5979613251386598',
#   'percentage_ll': '0.5864736950359506',
#   'percentage_ul': '0.6094489552413691',
#   'entry_id': '876'},
#  {'state': 'AL',
#   'collection_date': '2020-05-05',
#   'inpatient_beds_occupied_estimated': '8841.70345379689',
#   'count_ll': '8763.228019483158',
#   'count_ul': '8920.17888811062',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6458613979943122',
#   'percentage_ll': '0.6346646729975456',
#   'percentage_ul': '0.6570581229910788',
#   'entry_id': '881'},
#  {'state': 'AL',
#   'collection_date': '2020-05-06',
#   'inpatient_beds_occupied_estimated': '9095.383752885567',
#   'count_ll': '9020.306353580403',
#   'count_ul': '9170.46115219073',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6722958218081234',
#   'percentage_ll': '0.6610226710909101',
#   'percentage_ul': '0.6835689725253368',
#   'entry_id': '886'},
#  {'state': 'AL',
#   'collection_date': '2020-05-07',
#   'inpatient_beds_occupied_estimated': '8905.638320027767',
#   'count_ll': '8829.25364212559',
#   'count_ul': '8982.022997929944',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6705166224442016',
#   'percentage_ll': '0.6594057298583496',
#   'percentage_ul': '0.6816275150300537',
#   'entry_id': '891'},
#  {'state': 'AL',
#   'collection_date': '2020-05-08',
#   'inpatient_beds_occupied_estimated': '8710.418461538462',
#   'count_ll': '8632.020430230554',
#   'count_ul': '8788.816492846368',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6523741464189297',
#   'percentage_ll': '0.641261543516167',
#   'percentage_ul': '0.6634867493216923',
#   'entry_id': '896'},
#  {'state': 'AL',
#   'collection_date': '2020-05-09',
#   'inpatient_beds_occupied_estimated': '7527.111167967251',
#   'count_ll': '7443.656146273084',
#   'count_ul': '7610.566189661418',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.5727241018486222',
#   'percentage_ll': '0.5614595602298724',
#   'percentage_ul': '0.583988643467372',
#   'entry_id': '901'},
#  {'state': 'AL',
#   'collection_date': '2020-05-10',
#   'inpatient_beds_occupied_estimated': '7696.723295381861',
#   'count_ll': '7613.6995683715295',
#   'count_ul': '7779.747022392193',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.586447782046804',
#   'percentage_ll': '0.5752257987010827',
#   'percentage_ul': '0.5976697653925254',
#   'entry_id': '906'},
#  {'state': 'AL',
#   'collection_date': '2020-05-11',
#   'inpatient_beds_occupied_estimated': '8018.641558441559',
#   'count_ll': '7940.858111987827',
#   'count_ul': '8096.425004895291',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6116684673560735',
#   'percentage_ll': '0.599937233026699',
#   'percentage_ul': '0.623399701685448',
#   'entry_id': '911'},
#  {'state': 'AL',
#   'collection_date': '2020-05-12',
#   'inpatient_beds_occupied_estimated': '8623.974347873147',
#   'count_ll': '8548.35665836864',
#   'count_ul': '8699.59203737765',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6436532059632364',
#   'percentage_ll': '0.6320008556676475',
#   'percentage_ul': '0.6553055562588253',
#   'entry_id': '916'},
#  {'state': 'AL',
#   'collection_date': '2020-05-13',
#   'inpatient_beds_occupied_estimated': '8767.481004437708',
#   'count_ll': '8692.319419280873',
#   'count_ul': '8842.642589594545',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6537015615962984',
#   'percentage_ll': '0.642131217695612',
#   'percentage_ul': '0.6652719054969849',
#   'entry_id': '921'},
#  {'state': 'AL',
#   'collection_date': '2020-05-14',
#   'inpatient_beds_occupied_estimated': '8635.23938531588',
#   'count_ll': '8558.887866067787',
#   'count_ul': '8711.590904563971',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6552151036830702',
#   'percentage_ll': '0.6438486079711113',
#   'percentage_ul': '0.6665815993950291',
#   'entry_id': '926'},
#  {'state': 'AL',
#   'collection_date': '2020-05-15',
#   'inpatient_beds_occupied_estimated': '8699.740624272072',
#   'count_ll': '8622.750425528902',
#   'count_ul': '8776.73082301524',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6594432141727301',
#   'percentage_ll': '0.6482373941248987',
#   'percentage_ul': '0.6706490342205615',
#   'entry_id': '931'},
#  {'state': 'AL',
#   'collection_date': '2020-05-16',
#   'inpatient_beds_occupied_estimated': '7982.503460651115',
#   'count_ll': '7900.863216518842',
#   'count_ul': '8064.14370478339',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6150035385704176',
#   'percentage_ll': '0.6038620761329635',
#   'percentage_ul': '0.6261450010078716',
#   'entry_id': '936'},
#  {'state': 'AL',
#   'collection_date': '2020-05-17',
#   'inpatient_beds_occupied_estimated': '7911.008723958334',
#   'count_ll': '7828.156427219061',
#   'count_ul': '7993.861020697606',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6046718972895863',
#   'percentage_ll': '0.593588189597035',
#   'percentage_ul': '0.6157556049821375',
#   'entry_id': '941'},
#  {'state': 'AL',
#   'collection_date': '2020-05-18',
#   'inpatient_beds_occupied_estimated': '8289.955223880597',
#   'count_ll': '8209.643132784247',
#   'count_ul': '8370.267314976947',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6197025427794659',
#   'percentage_ll': '0.6084295842681',
#   'percentage_ul': '0.6309755012908318',
#   'entry_id': '946'},
#  {'state': 'AL',
#   'collection_date': '2020-05-19',
#   'inpatient_beds_occupied_estimated': '8822.38440860215',
#   'count_ll': '8744.973949086756',
#   'count_ul': '8899.794868117548',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6615891959798995',
#   'percentage_ll': '0.6504784013202811',
#   'percentage_ul': '0.6726999906395179',
#   'entry_id': '951'},
#  {'state': 'AL',
#   'collection_date': '2020-05-20',
#   'inpatient_beds_occupied_estimated': '9088.11776565465',
#   'count_ll': '9012.040142109061',
#   'count_ul': '9164.195389200237',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6868475991649269',
#   'percentage_ll': '0.675986561121858',
#   'percentage_ul': '0.6977086372079958',
#   'entry_id': '956'},
#  {'state': 'AL',
#   'collection_date': '2020-05-21',
#   'inpatient_beds_occupied_estimated': '9381.629801555064',
#   'count_ll': '9307.467529598543',
#   'count_ul': '9455.792073511588',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.7059928023783445',
#   'percentage_ll': '0.6952408494901373',
#   'percentage_ul': '0.7167447552665517',
#   'entry_id': '961'},
#  {'state': 'AL',
#   'collection_date': '2020-05-22',
#   'inpatient_beds_occupied_estimated': '9222.66902571361',
#   'count_ll': '9146.637478689445',
#   'count_ul': '9298.700572737776',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6902878835811452',
#   'percentage_ll': '0.6794858191880055',
#   'percentage_ul': '0.7010899479742849',
#   'entry_id': '966'},
#  {'state': 'AL',
#   'collection_date': '2020-05-23',
#   'inpatient_beds_occupied_estimated': '8459.20525187567',
#   'count_ll': '8376.593391453358',
#   'count_ul': '8541.817112297982',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6400290592081366',
#   'percentage_ll': '0.6293154234813487',
#   'percentage_ul': '0.6507426949349244',
#   'entry_id': '971'},
#  {'state': 'AL',
#   'collection_date': '2020-05-24',
#   'inpatient_beds_occupied_estimated': '8154.3474008574485',
#   'count_ll': '8070.508811414278',
#   'count_ul': '8238.185990300619',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6153985507246377',
#   'percentage_ll': '0.6045534006671023',
#   'percentage_ul': '0.6262437007821731',
#   'entry_id': '976'},
#  {'state': 'AL',
#   'collection_date': '2020-05-25',
#   'inpatient_beds_occupied_estimated': '8199.110069355253',
#   'count_ll': '8116.4009710490445',
#   'count_ul': '8281.819167661459',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6159031979256698',
#   'percentage_ll': '0.6049153660186879',
#   'percentage_ul': '0.6268910298326518',
#   'entry_id': '981'},
#  {'state': 'AL',
#   'collection_date': '2020-05-26',
#   'inpatient_beds_occupied_estimated': '8488.769853372434',
#   'count_ll': '8410.21197046435',
#   'count_ul': '8567.327736280518',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.6389811738648948',
#   'percentage_ll': '0.6277003638699903',
#   'percentage_ul': '0.6502619838597994',
#   'entry_id': '986'},
#  {'state': 'AL',
#   'collection_date': '2020-05-27',
#   'inpatient_beds_occupied_estimated': '9096.35545636086',
#   'count_ll': '9019.6922501859',
#   'count_ul': '9173.018662535822',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.679559748427673',
#   'percentage_ll': '0.6686478610371969',
#   'percentage_ul': '0.6904716358181491',
#   'entry_id': '991'},
#  {'state': 'AL',
#   'collection_date': '2020-05-28',
#   'inpatient_beds_occupied_estimated': '9336.287090332433',
#   'count_ll': '9261.375547140316',
#   'count_ul': '9411.198633524547',
#   'percentage_of_inpatient_beds_occupied_estimated': '0.7018987341772152',
#   'percentage_ll': '0.6911686858407532',
#   'percentage_ul': '0.7126287825136771',
#   'entry_id': '996'}]
